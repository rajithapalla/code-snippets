# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\data.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.tail(10)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89174       89175  I agree  I am a developer by profession
# 89175       89176  I agree  I am a developer by profession
# 89176       89177  I agree  I am a developer by profession
# 89177       89178  I agree  I am a developer by profession
# 89178       89179  I agree  I am a developer by profession
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89174     18-24 years old                                Employed, full-time
# 89175     25-34 years old                                Employed, full-time
# 89176     18-24 years old                                 Student, full-time
# ...

# %%
df.head(5)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
pd.set_option('display.max_columns', 85)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
pd.set_option('display.max_rows', 85)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
schema_df = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\schema.csv')
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\PC\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df[['ResponseId', 'MainBranch']]
# Out:
#        ResponseId                      MainBranch
# 0               1                   None of these
# 1               2  I am a developer by profession
# 2               3  I am a developer by profession
# 3               4  I am a developer by profession
# 4               5  I am a developer by profession
# ...           ...                             ...
# 89179       89180  I am a developer by profession
# 89180       89181  I am a developer by profession
# 89181       89182     I code primarily as a hobby
# 89182       89183  I am a developer by profession
# 89183       89184  I am a developer by profession
#
# [89184 rows x 2 columns]

# %%
schema_df.loc[0:10, 'qid':'question']
# Out:
#        qid             qname  \
# 0    QID16                S0
# 1    QID12          MetaInfo
# 2   QID310              Q310
# 3   QID312              Q120
# 4     QID1                S1
# 5     QID2        MainBranch
# 6   QID127               Age
# 7   QID296        Employment
# 8   QID308        RemoteWork
# 9   QID297  CodingActivities
# 10  QID190                S2
#
#                                              question
# 0   <div><span style="font-size:19px;"><strong>Hel...
# 1                                   Browser Meta Info
# 2   <div><span style="font-size:19px;"><strong>You...
# 3
# 4   <span style="font-size:22px; font-family: aria...
# 5   Which of the following options best describes ...
# 6                                 What is your age? *
# 7   Which of the following best describes your cur...
# 8   Which best describes your current work situation?
# 9   Which of the following best describes the code...
# 10  <span style="font-size:22px; font-family: aria...

# %%
people = {'first': ["Corey", 'Jane', 'John'],
         'last': ["Schafer", 'Doe', 'Doe'],
         'email': ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']}
df_people = pd.DataFrame(people)
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_people['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df_people.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df_people[['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df_people.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df_people.iloc[[0,1], 2] # iloc numbers
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
df_people.loc[[0,1], ['last', 'email']] # loc names
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=89184, step=1)

# %%
df_people.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df_people.set_index('email')
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df_people
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_people.set_index('email', inplace=True)

# %%
df_people
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df_people.loc['CoreyMSchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
df_people.reset_index(inplace=True)

# %%
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\data.csv', index_col='ResponseId')
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
schema_df = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\schema.csv', index_col='qname')

# %%
schema_df.loc['CodingActivities', 'question']
# Out:
# 'Which of the following best describes the code you write outside of work? Select all that apply.'

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID324
# AIBen                 QID316
# AIDev                 QID328
# AINext                QID320
# AIOpen                QID321
# AISearch              QID327
# AISelect              QID314
# AISent                QID315
# AITool                QID319
# Age                   QID127
# BuyNewTool            QID279
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# ICorPM                QID287
# Industry              QID326
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TechList              QID322
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# SOAI                  QID325
# S7                    QID131
# S6                    QID295
# S5                    QID313
# S4                     QID91
# S3                     QID61
# S2                    QID190
# S1                      QID1
# S0                     QID16
# RemoteWork            QID308
# Q310                  QID310
# Q120                  QID312
# PurchaseInfluence     QID278
# ProfessionalTech      QID304
# ...

# %%
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df_people[df_people['last'] == 'Doe']
# Out:
#                email first last
# 1  JaneDoe@email.com  Jane  Doe
# 2  JohnDoe@email.com  John  Doe

# %%
filt = (df_people['last'] == 'Doe') & (df_people['first'] == 'John')
df_people.loc[filt, 'email']
# Out:
# 2    JohnDoe@email.com
# Name: email, dtype: object

# %%
filt = (df_people['last'] == 'Schafer') | (df_people['first'] == 'John')
df_people.loc[filt, 'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df_people.loc[~filt, 'email']
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %%
high_salary = (df['CompTotal'] > 70000)
df.loc[high_salary]
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
# 6           I agree  I am a developer by profession  35-44 years old
# ...             ...                             ...              ...
# 89176       I agree  I am a developer by profession  25-34 years old
# 89178       I agree  I am a developer by profession  35-44 years old
# 89179       I agree  I am a developer by profession  45-54 years old
# 89180       I agree  I am a developer by profession  25-34 years old
# 89184       I agree  I am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
countries = ['United States of America', 'Mexico', 'India', 'Brazil']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# ResponseId
# 2        United States of America
# 3        United States of America
# 4        United States of America
# 7        United States of America
# 8        United States of America
#                    ...
# 89168                       India
# 89176    United States of America
# 89178                      Mexico
# 89179    United States of America
# 89180                      Brazil
# Name: Country, Length: 26919, dtype: object

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                               HTML/CSS;JavaScript;Python
# 8        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10          HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                       C#;C++;HTML/CSS;JavaScript;Python
# 12       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89173    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                 Dart;Java;Python;SQL
# 89182    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df_people.columns
# Out:
# Index(['email', 'first', 'last'], dtype='object')

# %%
df_people.columns = ['email', 'first name', 'last_name']
df_people
# Out:
#                      email first name last_name
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df_people.columns = [x.upper() for x in df_people.columns]
df_people
# Out:
#                      EMAIL FIRST NAME LAST_NAME
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df_people.columns = df_people.columns.str.replace(' ', '_')
df_people
# Out:
#                      EMAIL FIRST_NAME LAST_NAME
# 0  CoreyMSchafer@gmail.com      Corey   Schafer
# 1        JaneDoe@email.com       Jane       Doe
# 2        JohnDoe@email.com       John       Doe

# %%
df_people.rename(columns={'FIRST_NAME': 'first', 'LAST_NAME':'last'}, inplace=True)
df_people
# Out:
#                      EMAIL  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df_people.columns = [x.lower() for x in df_people.columns]
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df_people.loc[2] = ['JohnSmith@email.com', 'John', 'Smith']
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2      JohnSmith@email.com   John    Smith

# %%
df_people.loc[2, ['email', 'last']] = ['JohnDoe@email.com', 'Doe']
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df_people.loc[2, 'last'] = 'Smith'
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John    Smith

# %%
df_people.at[2, 'last'] = 'Doe' # at works for only single value
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
fil = (df_people['email'] =='JohnDoe@email.com')

# %%
df_people.loc[fil, 'last'] = 'Smith'
df_people.loc[fil, 'last'] = 'Doe'
df_people
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
df_people['email'] = df_people['email'].str.lower()
df_people
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com   John      Doe

# %%
# apply, applymap, replace
df_people['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df_people['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df_people['email'] = df_people['email'].apply(update_email)
df_people
# Out:
#                      email  first     last
# 0  COREYMSCHAFER@GMAIL.COM  Corey  Schafer
# 1        JANEDOE@EMAIL.COM   Jane      Doe
# 2        JOHNDOE@EMAIL.COM   John      Doe

# %%
df_people['email'] = df_people['email'].apply(lambda x: x.lower())
df_people
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com   John      Doe

# %%
df_people.apply(len)
# Out:
# email    3
# first    3
# last     3
# dtype: int64

# %%
df_people.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df_people.apply(pd.Series.min)
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %%
df_people.apply(lambda x: x.min())
# Out:
# email    coreymschafer@gmail.com
# first                      Corey
# last                         Doe
# dtype: object

# %%
df_people.applymap(len)
# Out:
#    email  first  last
# 0     23      5     7
# 1     17      4     3
# 2     17      4     3

# %%
df_people.applymap(str.upper)
# Out:
#                      email  first     last
# 0  COREYMSCHAFER@GMAIL.COM  COREY  SCHAFER
# 1        JANEDOE@EMAIL.COM   JANE      DOE
# 2        JOHNDOE@EMAIL.COM   JOHN      DOE

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryUSD'}, inplace=True)
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes':True, 'No':False})
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df_people
# Out:
#                      email  first     last
# 0  coreymschafer@gmail.com  Corey  Schafer
# 1        janedoe@email.com   Jane      Doe
# 2        johndoe@email.com   John      Doe

# %%
df_people['first'].map({'Corey':'Chris'})
# Out:
# 0    Chris
# 1      NaN
# 2      NaN
# Name: first, dtype: object

# %%
df_people['first'].replace({'Corey':'Chris'})
# Out:
# 0    Chris
# 1     Jane
# 2     John
# Name: first, dtype: object

# %%
df_people['full_name'] = df_people['first'] + ' ' + df_people['last']
df_people
# Out:
#                      email  first     last      full_name
# 0  coreymschafer@gmail.com  Corey  Schafer  Corey Schafer
# 1        janedoe@email.com   Jane      Doe       Jane Doe
# 2        johndoe@email.com   John      Doe       John Doe

# %%
df_people.drop(columns = ['first', 'last'], inplace=True)
df_people
# Out:
#                      email      full_name
# 0  coreymschafer@gmail.com  Corey Schafer
# 1        janedoe@email.com       Jane Doe
# 2        johndoe@email.com       John Doe

# %%
df_people[['first', 'last']] = df_people['full_name'].str.split(' ', expand=True)

# %%
df_people
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com       John Doe   John      Doe

# %%
# new_row = pd.DataFrame({'email':[None], 'full_name':[None], 'first': 'Tony', 'last':'Guy'})
# df_people = df_people.append(new_row, ignore_index=True, sort=False)
# df_people

# %%
df_people
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe
# 2        johndoe@email.com       John Doe   John      Doe

# %%
people1 = {
    'first': ['Tony', 'Steve'], 
    'last': ['Stark', 'Rogers'], 
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people1)
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
# df_people = df_people.append(df2, ignore_index=True, sort=False)

# %%
df_people.drop(index = 2, inplace=True)

# %%
df_people
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        janedoe@email.com       Jane Doe   Jane      Doe

# %%
filt = df_people['last'] == 'Doe'
df_people.drop(index = df_people[filt].index, inplace=True)

# %%
df_people
# Out:
#                      email      full_name  first     last
# 0  coreymschafer@gmail.com  Corey Schafer  Corey  Schafer

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df2.sort_values(by='last', ascending=False)
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df2.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df2.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df2.sort_index()
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df2['first'].sort_values()
# Out:
# 1    Steve
# 0     Tony
# Name: first, dtype: object

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# ResponseId
# 88348       Afghanistan  9203683.0
# 86039       Afghanistan    68000.0
# 1335        Afghanistan     2403.0
# 57362       Afghanistan     2288.0
# 17873       Afghanistan     1144.0
# 36049       Afghanistan      915.0
# 53322       Afghanistan      794.0
# 41679       Afghanistan      648.0
# 39427       Afghanistan       48.0
# 37956       Afghanistan       41.0
# 2642        Afghanistan       33.0
# 2301        Afghanistan        NaN
# 3911        Afghanistan        NaN
# 4222        Afghanistan        NaN
# 4410        Afghanistan        NaN
# 10143       Afghanistan        NaN
# 10377       Afghanistan        NaN
# 14420       Afghanistan        NaN
# 15959       Afghanistan        NaN
# 20378       Afghanistan        NaN
# 21498       Afghanistan        NaN
# 21673       Afghanistan        NaN
# 23095       Afghanistan        NaN
# 26532       Afghanistan        NaN
# 27885       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# ResponseId
# 53269    74351432.0
# 77849    73607918.0
# 66224    72714292.0
# 28122    57513831.0
# 19680    36573181.0
# 55103    17612921.0
# 80587    11000000.0
# 83680    10319366.0
# 47798     9915585.0
# 88348     9203683.0
# Name: SalaryUSD, dtype: float64

# %%
df[['Country', 'LanguageHaveWorkedWith', 'SalaryUSD']].nsmallest(10, 'SalaryUSD')
# Out:
#                                  Country  \
# ResponseId
# 47424                           Bulgaria
# 17986                              China
# 64956                            Germany
# 2244                               India
# 63214                              India
# 41417                          Indonesia
# 85525                          Indonesia
# 13709       Iran, Islamic Republic of...
# 52430       Iran, Islamic Republic of...
# 87481                            Lebanon
#
#                                        LanguageHaveWorkedWith  SalaryUSD
# ResponseId
# 47424                                                  C#;SQL        1.0
# 17986                          HTML/CSS;JavaScript;TypeScript        1.0
# 64956       Bash/Shell (all shells);C++;Dart;Java;Kotlin;Rust        1.0
# 2244                                              Perl;Python        1.0
# 63214                        C;HTML/CSS;JavaScript;Python;SQL        1.0
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 74963.0

# %%
df.describe()
# Out:
#           CompTotal       WorkExp     SalaryUSD
# count  4.822500e+04  43579.000000  4.801900e+04
# mean   1.036807e+42     11.405126  1.031101e+05
# std    2.276847e+44      9.051989  6.814188e+05
# min    0.000000e+00      0.000000  1.000000e+00
# 25%    6.300000e+04      5.000000  4.390700e+04
# 50%    1.150000e+05      9.000000  7.496300e+04
# 75%    2.300000e+05     16.000000  1.216410e+05
# max    5.000000e+46     50.000000  7.435143e+07

# %%
df['SalaryUSD'].describe()
# Out:
# count    4.801900e+04
# mean     1.031101e+05
# std      6.814188e+05
# min      1.000000e+00
# 25%      4.390700e+04
# 50%      7.496300e+04
# 75%      1.216410e+05
# max      7.435143e+07
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].count()
# Out:
# 48019

# %%
df['MainBranch'].value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                           67237
# I am not primarily a developer, but I write code sometimes as part of my work/studies     8954
# I am learning to code                                                                     4961
# I code primarily as a hobby                                                               4960
# I used to be a developer by profession, but no longer am                                  1861
# None of these                                                                             1211
# Name: count, dtype: int64

# %%
df['MainBranch'].value_counts(normalize=True)
# Out:
# MainBranch
# I am a developer by profession                                                           0.753913
# I am not primarily a developer, but I write code sometimes as part of my work/studies    0.100399
# I am learning to code                                                                    0.055627
# I code primarily as a hobby                                                              0.055615
# I used to be a developer by profession, but no longer am                                 0.020867
# None of these                                                                            0.013579
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 72666       I agree                     I am a developer by profession
# 46338       I agree                     I am a developer by profession
# 86269       I agree  I am not primarily a developer, but I write co...
# 85854       I agree                     I am a developer by profession
# 10000       I agree                     I am a developer by profession
# ...             ...                                                ...
# 89069       I agree  I am not primarily a developer, but I write co...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['MainBranch'].value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                           3986
# I am learning to code                                                                     726
# I am not primarily a developer, but I write code sometimes as part of my work/studies     500
# I code primarily as a hobby                                                               332
# I used to be a developer by profession, but no longer am                                   81
# Name: count, dtype: int64

# %%
country_grp['MainBranch'].value_counts().head(50)
# Out:
# Country              MainBranch
# Afghanistan          I am a developer by profession                                                             40
#                      I am learning to code                                                                      11
#                      I am not primarily a developer, but I write code sometimes as part of my work/studies       7
#                      I code primarily as a hobby                                                                 5
#                      I used to be a developer by profession, but no longer am                                    1
# Albania              I am a developer by profession                                                             46
#                      I am learning to code                                                                       8
#                      I am not primarily a developer, but I write code sometimes as part of my work/studies       4
# ...

# %%
country_grp['MainBranch'].value_counts().loc['India']
# Out:
# MainBranch
# I am a developer by profession                                                           3986
# I am learning to code                                                                     726
# I am not primarily a developer, but I write code sometimes as part of my work/studies     500
# I code primarily as a hobby                                                               332
# I used to be a developer by profession, but no longer am                                   81
# Name: count, dtype: int64

# %%
country_grp['MainBranch'].value_counts(normalize=True).loc['India']
# Out:
# MainBranch
# I am a developer by profession                                                           0.708622
# I am learning to code                                                                    0.129067
# I am not primarily a developer, but I write code sometimes as part of my work/studies    0.088889
# I code primarily as a hobby                                                              0.059022
# I used to be a developer by profession, but no longer am                                 0.014400
# Name: proportion, dtype: float64

# %%
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               915.0
# Albania                                 10741.0
# Algeria                                  8782.0
# Andorra                                 42836.0
# Angola                                   4302.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12763.0
# Yemen                                    6500.0
# Zambia                                   9687.0
# Zimbabwe                                12500.0
# Name: SalaryUSD, Length: 185, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['India']
# Out:
# 19023.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                        median           mean
# Country
# Afghanistan                             915.0  843636.090909
# Albania                               10741.0   29219.450000
# Algeria                                8782.0   10069.190476
# Andorra                               42836.0  120368.800000
# Angola                                 4302.0    4302.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...  12000.0   23068.851852
# Viet Nam                              12763.0   20995.956140
# Yemen                                  6500.0   15089.333333
# Zambia                                 9687.0   13897.800000
# Zimbabwe                              12500.0   26740.000000
#
# [185 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     89222.000000
# mean      142136.677435
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 2793

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
country_python_users = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_python_users
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_python_users], axis='columns', sort=False)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Grenada                                                 1
# Guinea-Bissau                                           1
# Liechtenstein                                           1
# Marshall Islands                                        1
# Saint Kitts and Nevis                                   1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10062
# Germany                                                               3686
# ...

# %%
python_df.rename(columns={'count':'NumRespondents', 'LanguageHaveWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Grenada                                                          1
# Guinea-Bissau                                                    1
# Liechtenstein                                                    1
# Marshall Islands                                                 1
# Saint Kitts and Nevis                                            1
#
#                                                     NumKnowsPython
# Country
# United States of America                                     10062
# ...

# %%
python_df['PerKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumRespondents'])*100
python_df
# Out:
#                                                     NumRespondents  \
# Country
# United States of America                                     18647
# Germany                                                       7328
# India                                                         5625
# United Kingdom of Great Britain and Northern Ir...            5552
# Canada                                                        3507
# ...                                                            ...
# Grenada                                                          1
# Guinea-Bissau                                                    1
# Liechtenstein                                                    1
# Marshall Islands                                                 1
# Saint Kitts and Nevis                                            1
#
#                                                     NumKnowsPython  \
# Country
# United States of America                                     10062
# ...

# %%
python_df.sort_values(by='PerKnowsPython', ascending=False, inplace=True)

# %%
python_df
# Out:
#                        NumRespondents  NumKnowsPython  PerKnowsPython
# Country
# Saint Lucia                         2               2           100.0
# Samoa                               1               1           100.0
# San Marino                          1               1           100.0
# Grenada                             1               1           100.0
# Liechtenstein                       1               1           100.0
# ...                               ...             ...             ...
# Suriname                            4               0             0.0
# Djibouti                            2               0             0.0
# Monaco                              2               0             0.0
# Gabon                               2               0             0.0
# Saint Kitts and Nevis               1               0             0.0
#
# [185 rows x 3 columns]

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    362.000000
# NumKnowsPython    188.000000
# PerKnowsPython     51.933702
# Name: Japan, dtype: float64

# %%
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df_drop = pd.DataFrame(people)

# %%
df_drop
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df_drop.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df_drop.dropna(axis='index', how='any')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df_drop.dropna(axis='index', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df_drop.dropna(axis='columns', how='all')
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df_drop.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df_drop.dropna(axis='index', how='any', subset=['email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 5   None      NaN      Anonymous@email.com     None
# 6     NA  Missing                       NA  Missing

# %%
df_drop.dropna(axis='index', how='any', subset=['last','email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@email.com       55
# 2   John      Doe        JohnDoe@email.com       63
# 6     NA  Missing                       NA  Missing

# %%
df_drop.replace('NA', np.nan, inplace=True)
df_drop.replace('Missing', np.nan, inplace=True)
df_drop
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df_drop.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63

# %%
df_drop.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df_drop.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@email.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df_drop.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@email.com  55
# 2   John      Doe        JohnDoe@email.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@email.com   0
# 6      0        0                        0   0

# %%
df_drop.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
df_drop['age'] = df_drop['age'].astype(int)  # if the column has none values we can't convert it to int, na is float type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 df_drop['age'] = df_drop['age'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df_drop['age'] = df_drop['age'].astype(float)

# %%
df_drop['age'].mean()
# Out:
# 46.75

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\data.csv', index_col = 'ResponseId', na_values=na_vals)

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 1     NaN
# 2      18
# 3      27
# 4      12
# 5       6
# 6      21
# 7       4
# 8       5
# 9      20
# 10      6
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
#     448 elif using_copy_on_write():
#     449     copy = False
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 0, '16', '33', '22', '30', '32', '7',
#        '35', '28', '40', '17', '29', '19', 51, '9', '38', '26', '34',
#        '25', '2', '45', '23', '31', '43', '1', '48', '41', '50', '39',
#        '42', '37', '36', '44', '46', '49', '47'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 13.966855378281009

# %%
df['YearsCode'].mode()
# Out:
# 0    10.0
# Name: YearsCode, dtype: float64

# %%
df_dt = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\ETH_1h.csv')
df_dt
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df_dt.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
df_dt['Date'] = pd.to_datetime(df_dt['Date'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_5740\3215957129.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_dt['Date'] = pd.to_datetime(df_dt['Date'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 df_dt['Date'] = pd.to_datetime(df_dt['Date'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
df_dt['Date'] = pd.to_datetime(df_dt['Date'], format='%Y-%m-%d %I-%p')

# %%
df_dt['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df_dt.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
# d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %I-%p')
df_dt = pd.read_csv('C:\\Users\\PC\\Desktop\\Pandas\\ETH_1h.csv', parse_dates=['Date'], date_format='%Y-%m-%d %I-%p')

# %%
df_dt
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df_dt['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df_dt['DayOfWeek'] = df_dt['Date'].dt.day_name()
df_dt
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
df_dt['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df_dt['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df_dt['Date'].max() - df_dt['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df_dt['Date'] >= '2020')
df_dt.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#       DayOfWeek
# 0        Friday
# ...

# %%
filt = (df_dt['Date'] >= '2019') & (df_dt['Date'] < '2020')
df_dt.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
filt = (df_dt['Date'] >= pd.to_datetime('2019-01-01')) & (df_dt['Date'] < pd.to_datetime('2020-01-01'))
df_dt.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df_dt.set_index('Date', inplace=True)

# %%
df_dt
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df_dt.loc['2020']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-03-13 20:00:00     Friday
# ...

# %%
df_dt['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df_dt['2020-01':'2020-02']['Close'].mean()
# Out:
# 195.1655902777778

# %%
df_dt.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
df_dt['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs = df_dt['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
highs.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_dt.resample('W').max()
# Out:
#             Symbol    Open    High     Low   Close       Volume  DayOfWeek
# Date
# 2017-07-02  ETHUSD  292.54  293.73  284.87  292.54   7081816.11     Sunday
# 2017-07-09  ETHUSD  285.00  285.00  282.31  282.58   6082287.50  Wednesday
# 2017-07-16  ETHUSD  238.81  240.33  238.00  238.47  23582117.48  Wednesday
# 2017-07-23  ETHUSD  245.55  249.40  234.97  245.55  31082353.62  Wednesday
# 2017-07-30  ETHUSD  229.96  229.99  229.60  229.96   9214814.73  Wednesday
# ...            ...     ...     ...     ...     ...          ...        ...
# 2020-02-16  ETHUSD  286.39  290.00  285.10  286.39  13323454.31  Wednesday
# 2020-02-23  ETHUSD  285.30  287.13  282.00  285.30  12085035.32  Wednesday
# 2020-03-01  ETHUSD  276.91  278.13  274.28  276.91  19074673.60  Wednesday
# 2020-03-08  ETHUSD  247.62  253.01  245.01  247.62   8804126.61  Wednesday
# 2020-03-15  ETHUSD  207.79  208.65  205.83  207.79  19731142.71  Wednesday
#
# [142 rows x 7 columns]

# %%
w_agg = df_dt.resample('W').agg({'Close':'mean', 'High': 'max', 'Low':'min', 'Volume':'sum'})

# %%
w_agg.plot()
# Out:
# <Axes: xlabel='Date'>
